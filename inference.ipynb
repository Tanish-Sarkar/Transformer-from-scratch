# %%
from pathlib import Path
import torch
import torch.nn as nn
from config import get_config, latest_weights_file_path
from train import get_model, get_ds, run_validation
from translate import translate
# Out:
# Using device: cpu
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4 from config import get_config, latest_weights_file_path
#       5 from train import get_model, get_ds, run_validation
# ----> 6 from translate import translate
#
# File e:\Personal Learning\Computer coding\Data Science\Transformers\Transformer-from-scratch\translate.py:79
#      76     return tokenizer_tgt.decode(decoder_input[0].tolist())
#      78 #read sentence from argument
# ---> 79 translate(sys.argv[1] if len(sys.argv) > 1 else "I am not a very good a student.")
#
# File e:\Personal Learning\Computer coding\Data Science\Transformers\Transformer-from-scratch\translate.py:17, in translate(sentence)
#      15 tokenizer_src = Tokenizer.from_file(str(Path(config['tokenizer_file'].format(config['lang_src']))))
#      16 tokenizer_tgt = Tokenizer.from_file(str(Path(config['tokenizer_file'].format(config['lang_tgt']))))
# ---> 17 model = build_transformer(tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size(), config["seq_len"], config['seq_len'], d_model=config['d_model']).to(device)
#      19 # Load the pretrained weights
#      20 model_filename = latest_weights_file_path(config)
#
# File e:\Personal Learning\Computer coding\Data Science\Transformers\Transformer-from-scratch\model.py:259, in build_transformer(src_vocab_size, tgt_vocab_size, src_seq_len, tgt_seq_len, d_model, N, h, dropout, d_ff)
#     257     self_attention = MultiHeadAttentionBlock(d_model, h, dropout)
#     258     feed_forward = FeedForwadBlock(d_model, d_ff, dropout)
# --> 259     encoder_block = EncoderBlock(self_attention, feed_forward, dropout)
#     260     encoder_blocks.append(encoder_block)
#     262 encoder = Encoder(encoder_blocks)
#
# TypeError: __init__() missing 1 required positional argument: 'dropout'

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
config = get_config()
train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)

# Load the pretrained weights
model_filename = latest_weights_file_path(config)
state = torch.load(model_filename)
model.load_state_dict(state['model_state_dict'])
# Out:
# Using device: cpu
# Max length of source sentence: 309
# Max length of target sentence: 274
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 config = get_config()
#       5 train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
# ----> 6 model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)
#       8 # Load the pretrained weights
#       9 model_filename = latest_weights_file_path(config)
#
# File e:\Personal Learning\Computer coding\Data Science\Transformers\Transformer-from-scratch\train.py:177, in get_model(config, vocab_src_len, vocab_tgt_len)
#     176 def get_model(config, vocab_src_len, vocab_tgt_len):
# --> 177     model = build_transformer(vocab_src_len, vocab_tgt_len, config["seq_len"], config['seq_len'], d_model=config['d_model'])
#     178     return model
#
# File e:\Personal Learning\Computer coding\Data Science\Transformers\Transformer-from-scratch\model.py:259, in build_transformer(src_vocab_size, tgt_vocab_size, src_seq_len, tgt_seq_len, d_model, N, h, dropout, d_ff)
#     257     self_attention = MultiHeadAttentionBlock(d_model, h, dropout)
#     258     feed_forward = FeedForwadBlock(d_model, d_ff, dropout)
# --> 259     encoder_block = EncoderBlock(self_attention, feed_forward, dropout)
#     260     encoder_blocks.append(encoder_block)
#     262 encoder = Encoder(encoder_blocks)
#
# TypeError: __init__() missing 1 required positional argument: 'dropout'

# %%
run_validation(model, val_dataloader, tokenizer_src, tokenizer_tgt, config['seq_len'], device, lambda msg: print(msg), 0, None, num_examples=10)

# %%
t = translate("Why do I need to translate this?")

# %%
t = translate(34)
